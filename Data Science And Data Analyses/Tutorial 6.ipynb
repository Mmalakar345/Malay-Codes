# %% [markdown]
# # Read csv file

# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv')

# %%
df
# Out:
#           SYMBOL  SERIES         DATE1  PREV_CLOSE  OPEN_PRICE   HIGH_PRICE  \
# 0      20MICRONS      EQ   12-Aug-2022      105.65      106.00       110.75
# 1     21STCENMGM      EQ   12-Aug-2022       25.70       26.00        26.00
# 2      3IINFOLTD      EQ   12-Aug-2022       40.85       40.90        41.45
# 3        3MINDIA      EQ   12-Aug-2022    22726.80    22799.00     23000.00
# 4         3PLAND      EQ   12-Aug-2022       15.60       15.55        16.00
# ...          ...     ...           ...         ...         ...          ...
# 2230        ZOTA      EQ   12-Aug-2022      273.55      276.40       278.00
# 2231       ZUARI      EQ   12-Aug-2022      158.80      160.00       163.00
# 2232    ZUARIIND      EQ   12-Aug-2022      162.00      164.50       167.00
# 2233   ZYDUSLIFE      EQ   12-Aug-2022      381.70      383.75       388.50
# 2234   ZYDUSWELL      EQ   12-Aug-2022     1626.00     1611.20      1634.15
#
# ...

# %%
df['SYMBOL'].dtype
# Out:
# dtype('O')

# %%
print(df['SYMBOL'].dtype)
# Out:
# object

# %%
print(df['PREV_CLOSE'])
# Out:
# 0         105.65
# 1          25.70
# 2          40.85
# 3       22726.80
# 4          15.60
#           ...
# 2230      273.55
# 2231      158.80
# 2232      162.00
# 2233      381.70
# 2234     1626.00
# Name: PREV_CLOSE, Length: 2235, dtype: float64

# %%
print(df['PREV_CLOSE'].astype('category'))
# Out:
# 0         105.65
# 1          25.70
# 2          40.85
# 3       22726.80
# 4          15.60
#           ...
# 2230      273.55
# 2231      158.80
# 2232      162.00
# 2233      381.70
# 2234     1626.00
# Name: PREV_CLOSE, Length: 2235, dtype: category
# Categories (2033, float64): [0.55, 0.80, 0.90, 0.95, ..., 22726.8, 40584.1, 49011.1, 82500.7]
# C:\Users\avima\AppData\Local\Temp\ipykernel_3676\1744644861.py:1: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   print(df['PREV_CLOSE'].astype('category'))
